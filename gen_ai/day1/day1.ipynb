# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Artificial Intelligence will transform the way businesses",
    max_length=30
)

print(result)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will transform the way businesses and consumers interact with their products and services. One of the greatest benefits of AI is that it will become the dominant way to manage the various aspects of human interaction. While the Internet and social media have brought huge social change, human interaction has been a slow, tedious process that has led to a number of problems.\n\nThe first problem is the lack of a human assistant to assist you in the process. This can be frustrating and confusing. In order to make sure that you have a solid understanding of what is going on, we need to be able to identify the individual, and that will be the most important step in making the process as smooth as possible. In the next section, we will explore the challenges that AI poses to businesses, and how it can provide a greater understanding of what it is doing.\n\n1. The AI Challenge\n\nWhile some companies will try to take AI to AI solutions, the reality is that there is no perfect solution. The best solution is the one that allows you to interact with your business, and not make errors. While this is a great idea for businesses, it is not possible to take it to real-life solutions.\n\nThis is why Google, Facebook, Microsoft, Apple, and other large companies have created AI'}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


from transformers import pipeline

# Load GPT-2 model
story_generator = pipeline("text-generation", model="gpt2")

# Prompt for the game storyline
prompt = "The hero enters the ancient forest and discovers"

# Generate story continuation
result = story_generator(
    prompt,
    max_new_tokens=60,
    temperature=0.8,
    num_return_sequences=1
)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'temperature', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a group of thieves of a certain class. He confronts them and is shocked to be confronted by a powerful spirit-like spirit that will sacrifice himself and help him survive.
#
# After the hero is freed from the spirit, the spirit attacks him and the three of them are sent to the temple of

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import BertTokenizer

# Load pretrained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query
text = "Deep learning models are powerful"

# Tokenize the sentence
tokens = tokenizer.tokenize(text)

# Convert tokens to IDs (numbers used by model)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Tokens: ['deep', 'learning', 'models', 'are', 'powerful']
# Token IDs: [2784, 4083, 4275, 2024, 3928]

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We are still in the early stages of developing AI, but we are already seeing the potential of AI to revolutionize the world.\n\nThe future of Artificial Intelligence is uncertain. We'}]
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of human leaders, and that\'s not the way it should be. We need to become more open to this possibility, and we need to start thinking through the implications of what AI can accomplish.\n\nThe problem with AI is its very limited ability to solve any of the problems that humans face. You can\'t solve problems that human beings are not aware of. You can\'t solve problems that humans are not capable of. You can\'t solve problems that the human race could never solve. You can\'t solve problems that humans could never solve.\n\nThis is why AI is so difficult. It has to be able to solve the problems that humans face. And it has to do so without sacrificing human life. But it has to do so without sacrificing AI.\n\nThis is why there has been a lot of talk of the "human singularity." And I think there\'s a lot of evidence that this is the case.\n\nAnd I\'d like to ask you as well about the role of human leadership in AI, and how that can be addressed.\n\nI think it\'s about time that we started looking at human leadership—and I don\'t want to say a human leadership—rather than human intervention in AI. We probably lost a'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


from transformers import pipeline
generator = pipeline("text-generation", model = "gpt2")

prompt = "The future of Artificial Intelligence"
print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain. The'}]
# [{'generated_text': 'The future of Artificial Intelligence is uncertain, and even a few months ago the world\'s largest robotics firm, Google, said AI was not going to get off the ground.\n\n"We are trying to do it as fast as we can and as fast as we can get to," said Chris Schmidt, Google\'s chief executive. "We are going to continue to evolve. Our goal has been to develop the tools and technologies to do that."\n\nIn the meantime, Schmidt said it\'s important to remember that AI is still a relatively nascent and difficult subject to develop. That\'s because many of the same challenges that people have faced with robots have been solved with human hand-crafted robots.\n\n"There is a real disconnect between people\'s perceptions and the technological advances that have been made since then," he said. "I think that the future of AI may be as much a human-related as it is a machine-related issue."\n\nThat was the theme in a March 2014 New York Times article, which explored how artificial intelligence could help solve some of humanity\'s most pressing problems, like climate change, the threat of terrorism and health care.\n\nBut there is a catch: The AI challenge is much bigger than the physical challenge of robots being able to do all that. In'}]

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”


from transformers import pipeline

generator = pipeline("text-generation", model = "gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length = 50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: hey how are you
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# hey how are you "
#
# Kaiyan sighed.
#
# Nodding, she asked, "So, you're a bit like me?"
#
# "It's just that I have a really good sense of taste, so I guess that's why I'm able to eat things like this, huh? Ahh. At least you're able to catch your breath, right?"
#
# "Yeah, I guess so." Kaiyan nodded.
#
# Nodding, she said.
#
# "I've been doing this for quite some time, so I guess I should definitely give it a try."
#
# "Huh?"
#
# "So what are you doing? I'm just going to give it a try."
#
# "Y-yes. I've been doing this for quite some time, so I guess I should definitely give it a try."
#
# Kaiyan gave a little smile.
#
# If that's the case, then it wouldn't be much more than an embarrassing moment.
#
# Nodding, she asked with a smile.
#
# "The only difference is that I can take a taste as an appetizer and eat it with my mouth. Let's see, you've got a lot of people like me here."

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline
gpt2 = pipeline("text-generation", model = "gpt2")
distilgpt2 = pipeline("text-generation", model = "distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2: ", gpt2(prompt, max_length = 40))
print("DistilGPT2: ", distilgpt2(prompt, max_length = 40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2:  [{'generated_text': 'Artificial Intelligence will transform our lives. It will bring us one step closer to a better future, one that will allow us to live in a world where we can trust each other and work together. It will transform the world around us, and our family and friends. It will make us better people. It will make us more powerful. It will make us more empowered. It will make us more of an artist. It will make us more of a creator. It will make us more of a better person. It will make us better at our jobs and at our jobs as equals. It will make us more of a person who cares about his family and friends. It will make us happier and more confident, more and more independent. It will make us happier and more independent. It will make us happier and more creative. It will make us happier and more creative. It will make us more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more creative. It will make us happier and more'}]
# DistilGPT2:  [{'generated_text': 'Artificial Intelligence will transform your mind into a human. It will be a machine that can control your brain using artificial intelligence.\n\n\n\nThe project is a collaboration between Stanford University and Google. They are developing a machine that can control your brain using technology that can control all the brain functions.\nThe goal of the project is to develop the technology by combining "learning algorithms" of the brain and Google\'s algorithms. They are called "machine learning."\nWhen people do this, they are expected to be able to perform a lot of basic tasks.\n"We want to create a machine that can control an individual\'s behavior and understand the relationship between individuals and each other," said Richard Stoll, an assistant professor of the Stanford Laboratory. "This is part of the Google Brain project. It is a collaboration between Stanford University and Google."\nStoll said that the project is about developing the technology by combining the technology and Google\'s algorithms.\n"It\'s a new idea that\'s been going on in the past," he said. "It\'s very exciting to see artificial intelligence replace human intelligence.\n"We are very excited about what this will be like and how it will evolve."'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.


from transformers import pipeline
gpt2 = pipeline("text-generation", model = "gpt2")
distilgpt2 = pipeline("text-generation", model = "distilgpt2")

prompt = "Educational Tool for Classroom Learning"

print("GPT2: ", gpt2(prompt, max_length = 40))
print("DistilGPT2: ", distilgpt2(prompt, max_length = 40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2:  [{'generated_text': 'Educational Tool for Classroom Learning in the Schools of the Mid and Late 1980\'s.\n\nThe following is an excerpt from a study conducted by the Center for American Progress (CAP) in 2001.\n\n"The research indicates that the typical teacher in a middle school is far less likely to teach a material that is not appropriate for that grade. For example, the teacher may teach a lesson that is not appropriate for a grade that is not appropriate for that grade. This is not an apples to apples comparison of how the classroom works."\n\nThe CAP\'s study found that teachers who taught to students in the middle and late 1980\'s were much less likely to learn about issues that are important to students than teachers who taught to students in the early 1970\'s.\n\n"The CAP study also found that teachers who taught to students in the early 1970\'s were much less likely to teach topics that are important to students than teachers who taught to students in the early 1980\'s," the CAP\'s report states. "This finding was supported by a study of teachers in the mid-1990s that found that teachers who taught to students in the late 1980\'s were more likely to teach topics that are important to students than teachers who taught to students in the early 1980\'s."\n\n"The CAP study further found'}]
# DistilGPT2:  [{'generated_text': 'Educational Tool for Classroom Learning.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]
